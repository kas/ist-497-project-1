# %% [markdown]
# # Feature Selection
#
# * Coleman-Liau score (CLScore)
# * RIX and LIX indices
# * Formality measure (fmeasure)
# * Number of uppercase words, presence of questionmarks and exclamation marks in headlines (titles), and the length of the title (number of words) are the most important content features
#
#
# * The character n-gram features and the word 1-gram feature appear to contribute most to performance
#     * Character n-grams are known to capture writing style
#
#
# * headline: word count
# * body: 1. Informality: We compute the frequencies of two informality indicators, namely internet slang and bait words. Additionally, the length of news bodies is also an input feature.
#
#
# * Sent length, word length, ratio of stop words to content words

# %%
# get the data

import json
import os
import pandas as pd

# https://github.com/ipython/ipython/issues/10123
directory_path = os.getcwd()
dataset_no_figures_path = directory_path + '/../data/dataset_no_figures/'

truth_classes = {}

with open(dataset_no_figures_path + 'truth_train.jsonl') as f:
    for line in f:
        truth = json.loads(line)
        truth_classes[truth['id']] = truth['truthClass']
        
df = pd.DataFrame()

with open(dataset_no_figures_path + 'instances_train.jsonl') as f:
    for line in f:
        instance = json.loads(line)
        data = pd.DataFrame({'postText': instance['postText'], 'truthClass': truth_classes[instance['id']]}, index=[instance['id']])
        df = df.append(data)
        
print(df)
# Out:
#                                                 postText    truthClass
# 0      Apple's iOS 9 'App thinning' feature will give...  no-clickbait
# 1      RT @kenbrown12: Emerging market investors are ...  no-clickbait
# 2      U.S. Soccer should start answering tough quest...     clickbait
# 3      How theme parks like Disney World left the mid...  no-clickbait
# 4      Could light bulbs hurt your health? One compan...     clickbait
# 5      13 classic ’00s songs that were actually meant...     clickbait
# 6      Dez Bryant is reportedly considering skipping ...  no-clickbait
# 7      Pregnant mother of 12 accused of keeping kids ...  no-clickbait
# 8      RT @fionamatthias: 10 ways the expat life Is l...  no-clickbait
# 9      House #GOP plans two days of debate, Friday sh...  no-clickbait
# 10     Azeri government behind foreign media ban, say...  no-clickbait
# 11     Only one in three of us complain when we are u...  no-clickbait
# 12     An open letter to Jerry Seinfeld from a "polit...  no-clickbait
# 13     Britain forced to withdraw spies after Russia ...  no-clickbait
# 14     Tourists detained in Malaysia for getting nake...     clickbait
# 15     RT @PhilipRucker: Jeb's super PAC unlikely to ...  no-clickbait
# 16     John Rohatinsky backs drug allegations made ag...  no-clickbait
# 17     Chinese women are growing their armpit hair li...  no-clickbait
# 18      The brutal dictatorship the world keeps ignoring     clickbait
# 19     RT @BBCWalesNews: Caerphilly farmer may get pa...     clickbait
# 20     RT @TheFix: The president's 'bully pulpit' is ...  no-clickbait
# 21         Man dies when car plunges from parking garage     clickbait
# 22     5 inconsistencies in 'Jurassic World' that wil...     clickbait
# 23     Why Christopher Lee made villainy sexy: via @C...  no-clickbait
# 24     Greece nearing compromise deal on EU debts, sa...  no-clickbait
# 25     A hero dog leapt in front of a school bus to p...  no-clickbait
# 26     Breaking News: House Rejects Trade Bills, as D...  no-clickbait
# 27     Pornhub is trying to make the first sex tape i...  no-clickbait
# 28     RT @BuzzFeedAnimals: What it’s like to grow up...  no-clickbait
# 29     A tour of the Earth, through the lens of an as...  no-clickbait
# ...                                                  ...           ...
# 17551  Jenni Murray: 'I want to see how women run the...  no-clickbait
# 17552  Six million Americans have stopped paying thei...  no-clickbait
# 17553  .@MelbourneCity limps to 1-1 A-League draw wit...  no-clickbait
# 17554  Martin Shkreli price-hike drug Daraprim reprod...  no-clickbait
# 17555   24-hour work shifts can wreak havoc on the heart     clickbait
# 17556  US general accuses Russia, Iran of boosting Ta...  no-clickbait
# 17557  How AI could stop those awkward moments when y...     clickbait
# 17558  Suspect in the shooting of Joe McKnight was re...  no-clickbait
# 17559  'They're sold like shoes': #Cambodia's buildin...     clickbait
# 17560  Formula One's most valuable teams:\n\n1. Ferra...  no-clickbait
# 17561  How @realaminablue went from video vixen to @K...  no-clickbait
# 17562  Fund NHS entirely with National Insurance, Lab...  no-clickbait
# 17563  .@aamir_khan's fitness journey for #Dangal - R...  no-clickbait
# 17564  Quick-thinking pedestrians extinguish a lorry ...  no-clickbait
# 17565  Rate ripoff: Some families are paying over $1,...     clickbait
# 17566  2,000-year-old preserved body of the Lady of D...  no-clickbait
# 17567  Obama says the U.S. is divided because 'people...  no-clickbait
# 17568  Current and former NFL players shared their fe...  no-clickbait
# 17569  #TheApprentice: the double firing was unfair, ...  no-clickbait
# 17570  Former Jets, USC RB Joe McKnight fatally shot ...  no-clickbait
# 17571  Country music star Luke Bryan hits back at 'in...  no-clickbait
# 17572                        We'll always have Newsweek.     clickbait
# 17573  What to do if your Android's been hit by the G...  no-clickbait
# 17574  18 uplifting documentaries guaranteed to put a...     clickbait
# 17575  The MLB All-Star game will no longer determine...  no-clickbait
# 17576  Just one glass of white a day can raise risk o...  no-clickbait
# 17577  12 things you realize at the end of a relation...     clickbait
# 17578                                     😱😱😱😱😱😱😱😱😱😱😱😱😱😱     clickbait
# 17579  Frenchs Forest high school may have to make wa...  no-clickbait
# 17580                                     Oh Jeff… #bruh  no-clickbait
#
# [17581 rows x 2 columns]

# %%
# preprocess the data

# TODO remove newlines from postText? (e.g., \n in 17560)

# %%
# get the features

from collections import Counter
from nltk import ngrams
# TODO
# from nltk.tokenize import RegexpTokenizer, sent_tokenize, word_tokenize
from nltk.tokenize import sent_tokenize, word_tokenize
from string import ascii_lowercase, ascii_uppercase
import nltk


# https://stackoverflow.com/questions/10677020/real-word-count-in-nltk
def number_of_words(text):
# TODO
#     regexptokenizer = RegexpTokenizer(r'\w+')
#     words = regexptokenizer.tokenize(text)
    words = word_tokenize(text)
    return len(words)


def number_of_uppercase_words(text):
    words = word_tokenize(text)
    n_of_uppercase_words = 0
    for word in words:
        if word[0] in ascii_uppercase:
            n_of_uppercase_words += 1
    return n_of_uppercase_words


def is_exclamation_question_mark_present(text):
    return '!' in text or '?' in text


def lix(text):
    # TODO should we return 0?
    if len(sent_tokenize(text)) == 0:
        return 0
    return number_of_words(text) / len(sent_tokenize(text))


def rix(text):
    lw = 0
    words = word_tokenize(text)
    for word in words:
        if len(word) >= 7:
            lw += 1
    # TODO should we return 0?
    if len(sent_tokenize(text)) == 0:
        return 0
    return lw / len(sent_tokenize(text))


# https://stackoverflow.com/questions/10674832/count-verbs-nouns-and-other-parts-of-speech-with-pythons-nltk
def formality_measure(text):
    tokenized_text = nltk.word_tokenize(text.lower())
    t = nltk.Text(tokenized_text)
    pos_tags = nltk.pos_tag(t)
    counts = Counter(tag for word,tag in pos_tags)
    return (counts['NN'] + counts['NNP'] + counts['NNS'] + counts['JJ'] + counts['JJR'] + counts['JJS'] + counts['IN'] + counts['DT'] + counts['PDT'] + counts['WDT'] - counts['PRP'] - counts['PRP$'] - counts['WP'] - counts['WP$'] - counts['VB'] - counts['VBD'] - counts['VBG'] - counts['VBN'] - counts['VBP'] - counts['VBZ'] - counts['RB'] - counts['RBR'] - counts['RBS'] - counts['WRB'] - counts['UH'] + 100) / 2


# https://en.wikipedia.org/wiki/Coleman%E2%80%93Liau_index
def clindex(text):
    text_lower = text.lower()
    number_of_letters = 0
    for character in text_lower:
        if character in ascii_lowercase:
            number_of_letters += 1
    number_of_sentences = len(sent_tokenize(text))
    n_of_words = number_of_words(text)
    l = 0
    s = 0
    # TODO should l and s be 0?
    if n_of_words == 0:
        pass
    else:
        # l = Letters ÷ Words × 100
        l = number_of_letters / n_of_words * 100
        # s = Sentences ÷ Words × 100
        s = number_of_sentences / n_of_words * 100
    return 0.0588 * l - 0.296 * s - 15.8


def character_1_grams(text):
    characters = [c for c in text]
    onegrams = ngrams(characters, 1)
    return [gram for gram in onegrams]


def character_2_grams(text):
    if len(text) == 0:
        return []
    characters = [c for c in text]
    twograms = ngrams(characters, 2)
    return [gram for gram in twograms]


def character_3_grams(text):
    if len(text) <= 1:
        return []
    characters = [c for c in text]
    threegrams = ngrams(characters, 3)
    return [gram for gram in threegrams]


def word_1_grams(text):
    onegrams = ngrams(word_tokenize(text), 1)
    return [gram for gram in onegrams]


df['number_of_words'] = None
df['number_of_uppercase_words'] = None
df['is_exclamation_question_mark_present'] = None
df['lix'] = None
df['rix'] = None
df['formality_measure'] = None
df['clindex'] = None
df['character_1_grams'] = None
df['character_2_grams'] = None
df['character_3_grams'] = None
df['word_1_grams'] = None
for i in df.index:
    df.loc[i]['number_of_words'] = number_of_words(df.loc[i]['postText'])
    df.loc[i]['number_of_uppercase_words'] = number_of_uppercase_words(df.loc[i]['postText'])
    df.loc[i]['is_exclamation_question_mark_present'] = is_exclamation_question_mark_present(df.loc[i]['postText'])
    df.loc[i]['lix'] = lix(df.loc[i]['postText'])
    df.loc[i]['rix'] = rix(df.loc[i]['postText'])
    df.loc[i]['formality_measure'] = formality_measure(df.loc[i]['postText'])
    df.loc[i]['clindex'] = clindex(df.loc[i]['postText'])
    df.loc[i]['character_1_grams'] = character_1_grams(df.loc[i]['postText'])
    df.loc[i]['character_2_grams'] = character_2_grams(df.loc[i]['postText'])
    df.loc[i]['character_3_grams'] = character_3_grams(df.loc[i]['postText'])
    df.loc[i]['word_1_grams'] = word_1_grams(df.loc[i]['postText'])
print(df)
# Out:
#                                                 postText    truthClass  \
# 0      Apple's iOS 9 'App thinning' feature will give...  no-clickbait
# 1      RT @kenbrown12: Emerging market investors are ...  no-clickbait
# 2      U.S. Soccer should start answering tough quest...     clickbait
# 3      How theme parks like Disney World left the mid...  no-clickbait
# 4      Could light bulbs hurt your health? One compan...     clickbait
# 5      13 classic ’00s songs that were actually meant...     clickbait
# 6      Dez Bryant is reportedly considering skipping ...  no-clickbait
# 7      Pregnant mother of 12 accused of keeping kids ...  no-clickbait
# 8      RT @fionamatthias: 10 ways the expat life Is l...  no-clickbait
# 9      House #GOP plans two days of debate, Friday sh...  no-clickbait
# 10     Azeri government behind foreign media ban, say...  no-clickbait
# 11     Only one in three of us complain when we are u...  no-clickbait
# 12     An open letter to Jerry Seinfeld from a "polit...  no-clickbait
# 13     Britain forced to withdraw spies after Russia ...  no-clickbait
# 14     Tourists detained in Malaysia for getting nake...     clickbait
# 15     RT @PhilipRucker: Jeb's super PAC unlikely to ...  no-clickbait
# 16     John Rohatinsky backs drug allegations made ag...  no-clickbait
# 17     Chinese women are growing their armpit hair li...  no-clickbait
# 18      The brutal dictatorship the world keeps ignoring     clickbait
# 19     RT @BBCWalesNews: Caerphilly farmer may get pa...     clickbait
# 20     RT @TheFix: The president's 'bully pulpit' is ...  no-clickbait
# 21         Man dies when car plunges from parking garage     clickbait
# 22     5 inconsistencies in 'Jurassic World' that wil...     clickbait
# 23     Why Christopher Lee made villainy sexy: via @C...  no-clickbait
# 24     Greece nearing compromise deal on EU debts, sa...  no-clickbait
# 25     A hero dog leapt in front of a school bus to p...  no-clickbait
# 26     Breaking News: House Rejects Trade Bills, as D...  no-clickbait
# 27     Pornhub is trying to make the first sex tape i...  no-clickbait
# 28     RT @BuzzFeedAnimals: What it’s like to grow up...  no-clickbait
# 29     A tour of the Earth, through the lens of an as...  no-clickbait
# ...                                                  ...           ...
# 17551  Jenni Murray: 'I want to see how women run the...  no-clickbait
# 17552  Six million Americans have stopped paying thei...  no-clickbait
# 17553  .@MelbourneCity limps to 1-1 A-League draw wit...  no-clickbait
# 17554  Martin Shkreli price-hike drug Daraprim reprod...  no-clickbait
# 17555   24-hour work shifts can wreak havoc on the heart     clickbait
# 17556  US general accuses Russia, Iran of boosting Ta...  no-clickbait
# 17557  How AI could stop those awkward moments when y...     clickbait
# 17558  Suspect in the shooting of Joe McKnight was re...  no-clickbait
# 17559  'They're sold like shoes': #Cambodia's buildin...     clickbait
# 17560  Formula One's most valuable teams:\n\n1. Ferra...  no-clickbait
# 17561  How @realaminablue went from video vixen to @K...  no-clickbait
# 17562  Fund NHS entirely with National Insurance, Lab...  no-clickbait
# 17563  .@aamir_khan's fitness journey for #Dangal - R...  no-clickbait
# 17564  Quick-thinking pedestrians extinguish a lorry ...  no-clickbait
# 17565  Rate ripoff: Some families are paying over $1,...     clickbait
# 17566  2,000-year-old preserved body of the Lady of D...  no-clickbait
# 17567  Obama says the U.S. is divided because 'people...  no-clickbait
# 17568  Current and former NFL players shared their fe...  no-clickbait
# 17569  #TheApprentice: the double firing was unfair, ...  no-clickbait
# 17570  Former Jets, USC RB Joe McKnight fatally shot ...  no-clickbait
# 17571  Country music star Luke Bryan hits back at 'in...  no-clickbait
# 17572                        We'll always have Newsweek.     clickbait
# 17573  What to do if your Android's been hit by the G...  no-clickbait
# 17574  18 uplifting documentaries guaranteed to put a...     clickbait
# 17575  The MLB All-Star game will no longer determine...  no-clickbait
# 17576  Just one glass of white a day can raise risk o...  no-clickbait
# 17577  12 things you realize at the end of a relation...     clickbait
# 17578                                     😱😱😱😱😱😱😱😱😱😱😱😱😱😱     clickbait
# 17579  Frenchs Forest high school may have to make wa...  no-clickbait
# 17580                                     Oh Jeff… #bruh  no-clickbait
#
#       number_of_words number_of_uppercase_words  \
# 0                  16                         1
# 1                  21                         5
# 2                  15                         4
# 3                  11                         3
# 4                  18                         2
# 5                  12                         0
# 6                  18                         3
# 7                  12                         1
# 8                  18                         3
# 9                  17                         4
# 10                 11                         3
# 11                 15                         2
# 12                 14                         3
# 13                 14                         4
# 14                 11                         2
# 15                 32                         6
# 16                  9                         4
# 17                 13                         1
# 18                  7                         1
# 19                 17                         3
# 20                 20                         4
# 21                  8                         1
# 22                 13                         2
# 23                 10                         4
# 24                 11                         4
# 25                 15                         1
# 26                 12                         9
# 27                 11                         1
# 28                 16                         3
# 29                 15                         2
# ...               ...                       ...
# 17551              13                         2
# 17552               9                         2
# 17553              11                         2
# 17554               8                         3
# 17555               9                         0
# 17556              11                         5
# 17557              14                         2
# 17558              21                         3
# 17559              19                         1
# 17560              22                         5
# 17561              14                         2
# 17562              12                         8
# 17563              14                         3
# 17564              13                         3
# 17565              16                         2
# 17566              16                         2
# 17567              16                         2
# 17568              15                         4
# 17569              20                         5
# 17570              12                         6
# 17571              13                         3
# 17572               6                         2
# 17573              13                         3
# 17574              11                         0
# 17575              15                         5
# 17576              17                         1
# 17577              10                         0
# 17578               1                         0
# 17579              20                         2
# 17580               4                         2
#
#       is_exclamation_question_mark_present  lix   rix formality_measure  \
# 0                                    False   16     3                52
# 1                                    False   21     4              50.5
# 2                                    False   15     3                54
# 3                                    False   11     0              53.5
# 4                                     True    9   1.5                49
# 5                                    False   12     3                52
# 6                                    False   18     4                51
# 7                                    False   12     4                54
# 8                                    False   18     3                57
# 9                                    False   17     1              56.5
# 10                                   False   11     4                54
# 11                                   False   15     2                50
# 12                                   False   14     5              53.5
# 13                                   False   14     3                52
# 14                                   False   11     5                52
# 15                                   False   32     6                57
# 16                                   False    9     5              53.5
# 17                                   False   13     2              48.5
# 18                                   False    7     2              51.5
# 19                                   False   17     4                55
# 20                                   False   10     1              53.5
# 21                                   False    8     2                51
# 22                                   False   13     4                54
# 23                                   False   10     3              52.5
# 24                                   False   11     3                53
# 25                                   False   15     1                55
# 26                                   False   12     3              52.5
# 27                                   False   11     1                52
# 28                                   False   16     1              51.5
# 29                                   False   15     2                57
# ...                                    ...  ...   ...               ...
# 17551                                False   13     0              50.5
# 17552                                False    9     3              49.5
# 17553                                False  5.5   1.5              54.5
# 17554                                False    8     5                53
# 17555                                False    9     1                53
# 17556                                False   11     5                53
# 17557                                False   14     4              49.5
# 17558                                False   21     7              51.5
# 17559                                False   19     2              52.5
# 17560                                False  5.5  1.25                52
# 17561                                False   14     3              52.5
# 17562                                False   12     4              52.5
# 17563                                 True    7   1.5              52.5
# 17564                                False   13     5              53.5
# 17565                                False   16     1              54.5
# 17566                                False   16     2              53.5
# 17567                                False   16     4                50
# 17568                                False   15     4              54.5
# 17569                                False   20     2                54
# 17570                                False   12     2                52
# 17571                                False   13     3                53
# 17572                                False    6     1                49
# 17573                                False   13     3              50.5
# 17574                                False   11     3              51.5
# 17575                                False   15     4              52.5
# 17576                                False   17     1                54
# 17577                                False   10     2              52.5
# 17578                                False    1     1              50.5
# 17579                                False   20     5                56
# 17580                                False    4     0              50.5
#
#          clindex                                  character_1_grams  \
# 0          3.665  [(A,), (p,), (p,), (l,), (e,), (',), (s,), ( ,...
# 1        4.07048  [(R,), (T,), ( ,), (@,), (k,), (e,), (n,), (b,...
# 2        10.4507  [(U,), (.,), (S,), (.,), ( ,), (S,), (o,), (c,...
# 3        9.30545  [(H,), (o,), (w,), ( ,), (t,), (h,), (e,), (m,...
# 4        5.08444  [(C,), (o,), (u,), (l,), (d,), ( ,), (l,), (i,...
# 5        5.74333  [(1,), (3,), ( ,), (c,), (l,), (a,), (s,), (s,...
# 6        6.72889  [(D,), (e,), (z,), ( ,), (B,), (r,), (y,), (a,...
# 7        7.70333  [(P,), (r,), (e,), (g,), (n,), (a,), (n,), (t,...
# 8        3.78889  [(R,), (T,), ( ,), (@,), (f,), (i,), (o,), (n,...
# 9        4.59529  [(H,), (o,), (u,), (s,), (e,), ( ,), (#,), (G,...
# 10       14.1164  [(A,), (z,), (e,), (r,), (i,), ( ,), (g,), (o,...
# 11       2.61067  [(O,), (n,), (l,), (y,), ( ,), (o,), (n,), (e,...
# 12       8.96571  [(A,), (n,), ( ,), (o,), (p,), (e,), (n,), ( ,...
# 13       12.7457  [(B,), (r,), (i,), (t,), (a,), (i,), (n,), ( ,...
# 14       11.9782  [(T,), (o,), (u,), (r,), (i,), (s,), (t,), (s,...
# 15       2.56875  [(R,), (T,), ( ,), (@,), (P,), (h,), (i,), (l,...
# 16       19.4578  [(J,), (o,), (h,), (n,), ( ,), (R,), (o,), (h,...
# 17       7.70462  [(C,), (h,), (i,), (n,), (e,), (s,), (e,), ( ,...
# 18       15.2514  [(T,), (h,), (e,), ( ,), (b,), (r,), (u,), (t,...
# 19       9.78353  [(R,), (T,), ( ,), (@,), (B,), (B,), (C,), (W,...
# 20         0.938  [(R,), (T,), ( ,), (@,), (T,), (h,), (e,), (F,...
# 21          8.43  [(M,), (a,), (n,), ( ,), (d,), (i,), (e,), (s,...
# 22       11.3231  [(5,), ( ,), (i,), (n,), (c,), (o,), (n,), (s,...
# 23         8.288  [(W,), (h,), (y,), ( ,), (C,), (h,), (r,), (i,...
# 24          9.84  [(G,), (r,), (e,), (e,), (c,), (e,), ( ,), (n,...
# 25       3.39467  [(A,), ( ,), (h,), (e,), (r,), (o,), ( ,), (d,...
# 26       8.68333  [(B,), (r,), (e,), (a,), (k,), (i,), (n,), (g,...
# 27       4.49455  [(P,), (o,), (r,), (n,), (h,), (u,), (b,), ( ,...
# 28         2.195  [(R,), (T,), ( ,), (@,), (B,), (u,), (z,), (z,...
# 29       1.82667  [(A,), ( ,), (t,), (o,), (u,), (r,), ( ,), (o,...
# ...          ...                                                ...
# 17551  0.0153846  [(J,), (e,), (n,), (n,), (i,), ( ,), (M,), (u,...
# 17552    12.9244  [(S,), (i,), (x,), ( ,), (m,), (i,), (l,), (l,...
# 17553    3.94182  [(.,), (@,), (M,), (e,), (l,), (b,), (o,), (u,...
# 17554     23.865  [(M,), (a,), (r,), (t,), (i,), (n,), ( ,), (S,...
# 17555    5.08444  [(2,), (4,), (-,), (h,), (o,), (u,), (r,), ( ,...
# 17556    11.4436  [(U,), (S,), ( ,), (g,), (e,), (n,), (e,), (r,...
# 17557    11.9057  [(H,), (o,), (w,), ( ,), (A,), (I,), ( ,), (c,...
# 17558    8.83048  [(S,), (u,), (s,), (p,), (e,), (c,), (t,), ( ,...
# 17559    3.68632  [(',), (T,), (h,), (e,), (y,), (',), (r,), (e,...
# 17560   -7.01636  [(F,), (o,), (r,), (m,), (u,), (l,), (a,), ( ,...
# 17561    6.86571  [(H,), (o,), (w,), ( ,), (@,), (r,), (e,), (a,...
# 17562    12.1133  [(F,), (u,), (n,), (d,), ( ,), (N,), (H,), (S,...
# 17563   -1.96857  [(.,), (@,), (a,), (a,), (m,), (i,), (r,), (_,...
# 17564    15.8462  [(Q,), (u,), (i,), (c,), (k,), (-,), (t,), (h,...
# 17565     4.0325  [(R,), (a,), (t,), (e,), ( ,), (r,), (i,), (p,...
# 17566     5.5025  [(2,), (,,), (0,), (0,), (0,), (-,), (y,), (e,...
# 17567     6.2375  [(O,), (b,), (a,), (m,), (a,), ( ,), (s,), (a,...
# 17568    10.0587  [(C,), (u,), (r,), (r,), (e,), (n,), (t,), ( ,...
# 17569       7.71  [(#,), (T,), (h,), (e,), (A,), (p,), (p,), (r,...
# 17570    2.31333  [(F,), (o,), (r,), (m,), (e,), (r,), ( ,), (J,...
# 17571    9.06154  [(C,), (o,), (u,), (n,), (t,), (r,), (y,), ( ,...
# 17572   0.826667  [(W,), (e,), (',), (l,), (l,), ( ,), (a,), (l,...
# 17573    4.08615  [(W,), (h,), (a,), (t,), ( ,), (t,), (o,), ( ,...
# 17574       9.84  [(1,), (8,), ( ,), (u,), (p,), (l,), (i,), (f,...
# 17575    10.8427  [(T,), (h,), (e,), ( ,), (M,), (L,), (B,), ( ,...
# 17576    2.86588  [(J,), (u,), (s,), (t,), ( ,), (o,), (n,), (e,...
# 17577      4.172  [(1,), (2,), ( ,), (t,), (h,), (i,), (n,), (g,...
# 17578      -45.4  [(😱,), (😱,), (😱,), (😱,), (😱,), (😱,), (😱,), (😱,...
# 17579     10.944  [(F,), (r,), (e,), (n,), (c,), (h,), (s,), ( ,...
# 17580       -8.5  [(O,), (h,), ( ,), (J,), (e,), (f,), (f,), (…,...
#
#                                        character_2_grams  \
# 0      [(A, p), (p, p), (p, l), (l, e), (e, '), (', s...
# 1      [(R, T), (T,  ), ( , @), (@, k), (k, e), (e, n...
# 2      [(U, .), (., S), (S, .), (.,  ), ( , S), (S, o...
# 3      [(H, o), (o, w), (w,  ), ( , t), (t, h), (h, e...
# 4      [(C, o), (o, u), (u, l), (l, d), (d,  ), ( , l...
# 5      [(1, 3), (3,  ), ( , c), (c, l), (l, a), (a, s...
# 6      [(D, e), (e, z), (z,  ), ( , B), (B, r), (r, y...
# 7      [(P, r), (r, e), (e, g), (g, n), (n, a), (a, n...
# 8      [(R, T), (T,  ), ( , @), (@, f), (f, i), (i, o...
# 9      [(H, o), (o, u), (u, s), (s, e), (e,  ), ( , #...
# 10     [(A, z), (z, e), (e, r), (r, i), (i,  ), ( , g...
# 11     [(O, n), (n, l), (l, y), (y,  ), ( , o), (o, n...
# 12     [(A, n), (n,  ), ( , o), (o, p), (p, e), (e, n...
# 13     [(B, r), (r, i), (i, t), (t, a), (a, i), (i, n...
# 14     [(T, o), (o, u), (u, r), (r, i), (i, s), (s, t...
# 15     [(R, T), (T,  ), ( , @), (@, P), (P, h), (h, i...
# 16     [(J, o), (o, h), (h, n), (n,  ), ( , R), (R, o...
# 17     [(C, h), (h, i), (i, n), (n, e), (e, s), (s, e...
# 18     [(T, h), (h, e), (e,  ), ( , b), (b, r), (r, u...
# 19     [(R, T), (T,  ), ( , @), (@, B), (B, B), (B, C...
# 20     [(R, T), (T,  ), ( , @), (@, T), (T, h), (h, e...
# 21     [(M, a), (a, n), (n,  ), ( , d), (d, i), (i, e...
# 22     [(5,  ), ( , i), (i, n), (n, c), (c, o), (o, n...
# 23     [(W, h), (h, y), (y,  ), ( , C), (C, h), (h, r...
# 24     [(G, r), (r, e), (e, e), (e, c), (c, e), (e,  ...
# 25     [(A,  ), ( , h), (h, e), (e, r), (r, o), (o,  ...
# 26     [(B, r), (r, e), (e, a), (a, k), (k, i), (i, n...
# 27     [(P, o), (o, r), (r, n), (n, h), (h, u), (u, b...
# 28     [(R, T), (T,  ), ( , @), (@, B), (B, u), (u, z...
# 29     [(A,  ), ( , t), (t, o), (o, u), (u, r), (r,  ...
# ...                                                  ...
# 17551  [(J, e), (e, n), (n, n), (n, i), (i,  ), ( , M...
# 17552  [(S, i), (i, x), (x,  ), ( , m), (m, i), (i, l...
# 17553  [(., @), (@, M), (M, e), (e, l), (l, b), (b, o...
# 17554  [(M, a), (a, r), (r, t), (t, i), (i, n), (n,  ...
# 17555  [(2, 4), (4, -), (-, h), (h, o), (o, u), (u, r...
# 17556  [(U, S), (S,  ), ( , g), (g, e), (e, n), (n, e...
# 17557  [(H, o), (o, w), (w,  ), ( , A), (A, I), (I,  ...
# 17558  [(S, u), (u, s), (s, p), (p, e), (e, c), (c, t...
# 17559  [(', T), (T, h), (h, e), (e, y), (y, '), (', r...
# 17560  [(F, o), (o, r), (r, m), (m, u), (u, l), (l, a...
# 17561  [(H, o), (o, w), (w,  ), ( , @), (@, r), (r, e...
# 17562  [(F, u), (u, n), (n, d), (d,  ), ( , N), (N, H...
# 17563  [(., @), (@, a), (a, a), (a, m), (m, i), (i, r...
# 17564  [(Q, u), (u, i), (i, c), (c, k), (k, -), (-, t...
# 17565  [(R, a), (a, t), (t, e), (e,  ), ( , r), (r, i...
# 17566  [(2, ,), (,, 0), (0, 0), (0, 0), (0, -), (-, y...
# 17567  [(O, b), (b, a), (a, m), (m, a), (a,  ), ( , s...
# 17568  [(C, u), (u, r), (r, r), (r, e), (e, n), (n, t...
# 17569  [(#, T), (T, h), (h, e), (e, A), (A, p), (p, p...
# 17570  [(F, o), (o, r), (r, m), (m, e), (e, r), (r,  ...
# 17571  [(C, o), (o, u), (u, n), (n, t), (t, r), (r, y...
# 17572  [(W, e), (e, '), (', l), (l, l), (l,  ), ( , a...
# 17573  [(W, h), (h, a), (a, t), (t,  ), ( , t), (t, o...
# 17574  [(1, 8), (8,  ), ( , u), (u, p), (p, l), (l, i...
# 17575  [(T, h), (h, e), (e,  ), ( , M), (M, L), (L, B...
# 17576  [(J, u), (u, s), (s, t), (t,  ), ( , o), (o, n...
# 17577  [(1, 2), (2,  ), ( , t), (t, h), (h, i), (i, n...
# 17578  [(😱, 😱), (😱, 😱), (😱, 😱), (😱, 😱), (😱, 😱), (😱, 😱...
# 17579  [(F, r), (r, e), (e, n), (n, c), (c, h), (h, s...
# 17580  [(O, h), (h,  ), ( , J), (J, e), (e, f), (f, f...
#
#                                        character_3_grams  \
# 0      [(A, p, p), (p, p, l), (p, l, e), (l, e, '), (...
# 1      [(R, T,  ), (T,  , @), ( , @, k), (@, k, e), (...
# 2      [(U, ., S), (., S, .), (S, .,  ), (.,  , S), (...
# 3      [(H, o, w), (o, w,  ), (w,  , t), ( , t, h), (...
# 4      [(C, o, u), (o, u, l), (u, l, d), (l, d,  ), (...
# 5      [(1, 3,  ), (3,  , c), ( , c, l), (c, l, a), (...
# 6      [(D, e, z), (e, z,  ), (z,  , B), ( , B, r), (...
# 7      [(P, r, e), (r, e, g), (e, g, n), (g, n, a), (...
# 8      [(R, T,  ), (T,  , @), ( , @, f), (@, f, i), (...
# 9      [(H, o, u), (o, u, s), (u, s, e), (s, e,  ), (...
# 10     [(A, z, e), (z, e, r), (e, r, i), (r, i,  ), (...
# 11     [(O, n, l), (n, l, y), (l, y,  ), (y,  , o), (...
# 12     [(A, n,  ), (n,  , o), ( , o, p), (o, p, e), (...
# 13     [(B, r, i), (r, i, t), (i, t, a), (t, a, i), (...
# 14     [(T, o, u), (o, u, r), (u, r, i), (r, i, s), (...
# 15     [(R, T,  ), (T,  , @), ( , @, P), (@, P, h), (...
# 16     [(J, o, h), (o, h, n), (h, n,  ), (n,  , R), (...
# 17     [(C, h, i), (h, i, n), (i, n, e), (n, e, s), (...
# 18     [(T, h, e), (h, e,  ), (e,  , b), ( , b, r), (...
# 19     [(R, T,  ), (T,  , @), ( , @, B), (@, B, B), (...
# 20     [(R, T,  ), (T,  , @), ( , @, T), (@, T, h), (...
# 21     [(M, a, n), (a, n,  ), (n,  , d), ( , d, i), (...
# 22     [(5,  , i), ( , i, n), (i, n, c), (n, c, o), (...
# 23     [(W, h, y), (h, y,  ), (y,  , C), ( , C, h), (...
# 24     [(G, r, e), (r, e, e), (e, e, c), (e, c, e), (...
# 25     [(A,  , h), ( , h, e), (h, e, r), (e, r, o), (...
# 26     [(B, r, e), (r, e, a), (e, a, k), (a, k, i), (...
# 27     [(P, o, r), (o, r, n), (r, n, h), (n, h, u), (...
# 28     [(R, T,  ), (T,  , @), ( , @, B), (@, B, u), (...
# 29     [(A,  , t), ( , t, o), (t, o, u), (o, u, r), (...
# ...                                                  ...
# 17551  [(J, e, n), (e, n, n), (n, n, i), (n, i,  ), (...
# 17552  [(S, i, x), (i, x,  ), (x,  , m), ( , m, i), (...
# 17553  [(., @, M), (@, M, e), (M, e, l), (e, l, b), (...
# 17554  [(M, a, r), (a, r, t), (r, t, i), (t, i, n), (...
# 17555  [(2, 4, -), (4, -, h), (-, h, o), (h, o, u), (...
# 17556  [(U, S,  ), (S,  , g), ( , g, e), (g, e, n), (...
# 17557  [(H, o, w), (o, w,  ), (w,  , A), ( , A, I), (...
# 17558  [(S, u, s), (u, s, p), (s, p, e), (p, e, c), (...
# 17559  [(', T, h), (T, h, e), (h, e, y), (e, y, '), (...
# 17560  [(F, o, r), (o, r, m), (r, m, u), (m, u, l), (...
# 17561  [(H, o, w), (o, w,  ), (w,  , @), ( , @, r), (...
# 17562  [(F, u, n), (u, n, d), (n, d,  ), (d,  , N), (...
# 17563  [(., @, a), (@, a, a), (a, a, m), (a, m, i), (...
# 17564  [(Q, u, i), (u, i, c), (i, c, k), (c, k, -), (...
# 17565  [(R, a, t), (a, t, e), (t, e,  ), (e,  , r), (...
# 17566  [(2, ,, 0), (,, 0, 0), (0, 0, 0), (0, 0, -), (...
# 17567  [(O, b, a), (b, a, m), (a, m, a), (m, a,  ), (...
# 17568  [(C, u, r), (u, r, r), (r, r, e), (r, e, n), (...
# 17569  [(#, T, h), (T, h, e), (h, e, A), (e, A, p), (...
# 17570  [(F, o, r), (o, r, m), (r, m, e), (m, e, r), (...
# 17571  [(C, o, u), (o, u, n), (u, n, t), (n, t, r), (...
# 17572  [(W, e, '), (e, ', l), (', l, l), (l, l,  ), (...
# 17573  [(W, h, a), (h, a, t), (a, t,  ), (t,  , t), (...
# 17574  [(1, 8,  ), (8,  , u), ( , u, p), (u, p, l), (...
# 17575  [(T, h, e), (h, e,  ), (e,  , M), ( , M, L), (...
# 17576  [(J, u, s), (u, s, t), (s, t,  ), (t,  , o), (...
# 17577  [(1, 2,  ), (2,  , t), ( , t, h), (t, h, i), (...
# 17578  [(😱, 😱, 😱), (😱, 😱, 😱), (😱, 😱, 😱), (😱, 😱, 😱), (...
# 17579  [(F, r, e), (r, e, n), (e, n, c), (n, c, h), (...
# 17580  [(O, h,  ), (h,  , J), ( , J, e), (J, e, f), (...
#
#                                             word_1_grams
# 0      [(Apple,), ('s,), (iOS,), (9,), ('App,), (thin...
# 1      [(RT,), (@,), (kenbrown12,), (:,), (Emerging,)...
# 2      [(U.S.,), (Soccer,), (should,), (start,), (ans...
# 3      [(How,), (theme,), (parks,), (like,), (Disney,...
# 4      [(Could,), (light,), (bulbs,), (hurt,), (your,...
# 5      [(13,), (classic,), (’,), (00s,), (songs,), (t...
# 6      [(Dez,), (Bryant,), (is,), (reportedly,), (con...
# 7      [(Pregnant,), (mother,), (of,), (12,), (accuse...
# 8      [(RT,), (@,), (fionamatthias,), (:,), (10,), (...
# 9      [(House,), (#,), (GOP,), (plans,), (two,), (da...
# 10     [(Azeri,), (government,), (behind,), (foreign,...
# 11     [(Only,), (one,), (in,), (three,), (of,), (us,...
# 12     [(An,), (open,), (letter,), (to,), (Jerry,), (...
# 13     [(Britain,), (forced,), (to,), (withdraw,), (s...
# 14     [(Tourists,), (detained,), (in,), (Malaysia,),...
# 15     [(RT,), (@,), (PhilipRucker,), (:,), (Jeb,), (...
# 16     [(John,), (Rohatinsky,), (backs,), (drug,), (a...
# 17     [(Chinese,), (women,), (are,), (growing,), (th...
# 18     [(The,), (brutal,), (dictatorship,), (the,), (...
# 19     [(RT,), (@,), (BBCWalesNews,), (:,), (Caerphil...
# 20     [(RT,), (@,), (TheFix,), (:,), (The,), (presid...
# 21     [(Man,), (dies,), (when,), (car,), (plunges,),...
# 22     [(5,), (inconsistencies,), (in,), ('Jurassic,)...
# 23     [(Why,), (Christopher,), (Lee,), (made,), (vil...
# 24     [(Greece,), (nearing,), (compromise,), (deal,)...
# 25     [(A,), (hero,), (dog,), (leapt,), (in,), (fron...
# 26     [(Breaking,), (News,), (:,), (House,), (Reject...
# 27     [(Pornhub,), (is,), (trying,), (to,), (make,),...
# 28     [(RT,), (@,), (BuzzFeedAnimals,), (:,), (What,...
# 29     [(A,), (tour,), (of,), (the,), (Earth,), (,,),...
# ...                                                  ...
# 17551  [(Jenni,), (Murray,), (:,), ('I,), (want,), (t...
# 17552  [(Six,), (million,), (Americans,), (have,), (s...
# 17553  [(.,), (@,), (MelbourneCity,), (limps,), (to,)...
# 17554  [(Martin,), (Shkreli,), (price-hike,), (drug,)...
# 17555  [(24-hour,), (work,), (shifts,), (can,), (wrea...
# 17556  [(US,), (general,), (accuses,), (Russia,), (,,...
# 17557  [(How,), (AI,), (could,), (stop,), (those,), (...
# 17558  [(Suspect,), (in,), (the,), (shooting,), (of,)...
# 17559  [('They,), ('re,), (sold,), (like,), (shoes,),...
# 17560  [(Formula,), (One,), ('s,), (most,), (valuable...
# 17561  [(How,), (@,), (realaminablue,), (went,), (fro...
# 17562  [(Fund,), (NHS,), (entirely,), (with,), (Natio...
# 17563  [(.,), (@,), (aamir_khan,), ('s,), (fitness,),...
# 17564  [(Quick-thinking,), (pedestrians,), (extinguis...
# 17565  [(Rate,), (ripoff,), (:,), (Some,), (families,...
# 17566  [(2,000-year-old,), (preserved,), (body,), (of...
# 17567  [(Obama,), (says,), (the,), (U.S.,), (is,), (d...
# 17568  [(Current,), (and,), (former,), (NFL,), (playe...
# 17569  [(#,), (TheApprentice,), (:,), (the,), (double...
# 17570  [(Former,), (Jets,), (,,), (USC,), (RB,), (Joe...
# 17571  [(Country,), (music,), (star,), (Luke,), (Brya...
# 17572  [(We,), ('ll,), (always,), (have,), (Newsweek,...
# 17573  [(What,), (to,), (do,), (if,), (your,), (Andro...
# 17574  [(18,), (uplifting,), (documentaries,), (guara...
# 17575  [(The,), (MLB,), (All-Star,), (game,), (will,)...
# 17576  [(Just,), (one,), (glass,), (of,), (white,), (...
# 17577  [(12,), (things,), (you,), (realize,), (at,), ...
# 17578                                [(😱😱😱😱😱😱😱😱😱😱😱😱😱😱,)]
# 17579  [(Frenchs,), (Forest,), (high,), (school,), (m...
# 17580                   [(Oh,), (Jeff…,), (#,), (bruh,)]
#
# [17581 rows x 13 columns]

# %%
# normalize features

# TODO get features in range of [0,1] or [-1,1]?
# TODO convert all booleans to 0 and 1?
# TODO convert lix to five levels (0-4) based on this: very easy (0-24), easy (25-34), standard (35-44), difficult (45-54) and very difficult (more than 55)
# TODO convert rix to thirteen levels (0-13) based on this: 0.2, 0.5, 0.8, 1.3, 1.8, 2.4, 3.0, 3.7, 4.5, 5.3, 6.2, 7.2

# %%
# create train and test sets

# %%
# create error functions

# %%
# test models

# TODO try https://xgboost.ai
